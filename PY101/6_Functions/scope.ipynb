# %%
def elective_sub_grade(mark):
  threshold = 40

  mark = mark * 5
  return (mark > threshold)

# %%
def core_sub_grade(mark):
  return (mark > threshold)

# %%
mark = int(input("Enter your mark:"))
elective_sub_grade(mark)

core_sub_grade(mark)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 mark = int(input("Enter your mark:"))
# ----> 2 print(elective_sub_grade(mark), core_sub_grade(mark))
#
# Cell In[3], line 2, in core_sub_grade(mark)
#       1 def core_sub_grade(mark):
# ----> 2   return (mark > threshold)
#
# NameError: name 'threshold' is not defined
