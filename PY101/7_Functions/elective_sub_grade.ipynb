# %%
def elective_sub_grade(mark):
  """
  Determine if the elective sub-grade is passed.

  Args: 
    mark (int): The mark obtained in the elective subject.

  Returns:
    bool: True if the elective sub-grade is passed, False otherwise.

  """
  global threshold
  threshold = 40

  mark = mark * 5
  return (mark > threshold)

# %%
def core_sub_grade(mark):
  threshold = 40

  return (mark > threshold)

# %%
mark = int(input("Enter the mark obtained in the elective subject: "))
print(elective_sub_grade(mark))
print(core_sub_grade(mark))
# Out:
# True
# False
